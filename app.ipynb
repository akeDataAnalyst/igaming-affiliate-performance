# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Page Configuration
st.set_page_config(page_title="Growe Affiliate Integrity Dashboard", layout="wide")

st.title("🛡️ iGaming Affiliate Integrity & ROI Tracker")
st.markdown("""
This dashboard identifies **Bonus Hunters** and **Bot Traffic** in real-time to protect marketing margins.
""")

# 1. Load Data
@st.cache_data
def load_data():
    # Using the cleaned data from our previous work
    df = pd.read_csv('cleaned_affiliate_performance.csv')
    df['reg_date'] = pd.to_datetime(df['reg_date'])
    return df

df = load_data()

# 2. Sidebar Filters
st.sidebar.header("Filter Analytics")
selected_country = st.sidebar.multiselect("Select Country", options=df['country'].unique(), default=df['country'].unique())
selected_affiliate = st.sidebar.multiselect("Select Affiliate", options=df['affiliate_name'].unique(), default=df['affiliate_name'].unique())

# Filter data based on selection
filtered_df = df[(df['country'].isin(selected_country)) & (df['affiliate_name'].isin(selected_affiliate))]

# 3. Key Metrics (KPIs)
col1, col2, col3 = st.columns(3)
with col1:
    total_ngr = filtered_df['NGR'].sum()
    st.metric("Total Net Gaming Revenue (NGR)", f"${total_ngr:,.2f}", delta=None)
with col2:
    avg_bonus_ratio = filtered_df['Bonus'].sum() / (filtered_df['Deposit'].sum() + 1)
    st.metric("Avg Bonus-to-Deposit Ratio", f"{avg_bonus_ratio:.2f}", delta="-0.05", delta_color="inverse")
with col3:
    high_risk_count = len(filtered_df[filtered_df['Bonus'] > (filtered_df['Deposit'] * 2)])
    st.metric("High-Risk Players Detected", high_risk_count)

st.divider()

# 4. Visualizations
col_left, col_right = st.columns(2)

with col_left:
    st.subheader("Profitability by Affiliate (NGR)")
    fig, ax = plt.subplots()
    aff_summary = filtered_df.groupby('affiliate_name')['NGR'].sum().sort_values()
    colors = ['#ff4b4b' if x < 0 else '#00cc96' for x in aff_summary]
    aff_summary.plot(kind='barh', color=colors, ax=ax)
    st.pyplot(fig)

with col_right:
    st.subheader("Bonus vs. Deposit Risk Map")
    fig2, ax2 = plt.subplots()
    sns.scatterplot(data=filtered_df, x='Deposit', y='Bonus', hue='affiliate_name', ax=ax2)
    plt.plot([0, filtered_df['Deposit'].max()], [0, filtered_df['Deposit'].max()], 'r--')
    st.pyplot(fig2)

# 5. The "Red Flag" List
st.subheader("🚩 High-Risk Affiliate Segments (Bonus Abuse)")
# Grouping to show where bonus ratio is toxic
risk_table = filtered_df.groupby(['affiliate_name', 'country']).agg({
    'Deposit': 'sum',
    'Bonus': 'sum',
    'NGR': 'sum'
}).reset_index()
risk_table['Ratio'] = risk_table['Bonus'] / (risk_table['Deposit'] + 1)

# Display only high risk
st.dataframe(risk_table[risk_table['Ratio'] > 1.0].sort_values(by='Ratio', ascending=False), use_container_width=True)

st.success("Targeting active. Export this list to CRM for bonus capping.")

st.sidebar.markdown("---")
st.sidebar.write("👨‍💻 **Author:** Aklilu Abera")
st.sidebar.caption("Data Analyst | iGaming Intelligence")
# Out:
# 2026-01-30 15:09:55.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:55.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:55.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:55.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:55.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:56.178 No runtime found, using MemoryCacheStorageManager
# 2026-01-30 15:09:56.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:56.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:56.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:57.506 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:58.735 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:59.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:59.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:59.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:09:59.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:00.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:00.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:02.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:02.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:02.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:02.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:02.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:02.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:03.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:04.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:13.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:17.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:17.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:17.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:17.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:21.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:22.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:22.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:22.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:22.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 15:10:23.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())
